# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52179/Reinforcement_Learning/blob/main/RL_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# Part A - Machine Initialization
machines = ['A', 'B', 'C']

# Number of plays
N_play = 10

# Part B - Initialize N, R, Q and UCB
N = {machine: 0 for machine in machines}      # Participation count
R = {machine: 0 for machine in machines}      # Total reward
Q = {machine: 0.0 for machine in machines}    # Estimated Q-value
UCB = {machine: 0.0 for machine in machines}  # UCB value

total_reward = 0

print("----- UCB Multi-Armed Bandit -----")

for play in range(1, N_play + 1):

    # Part C - Calculate UCB
    for machine in machines:
        if N[machine] == 0:
            UCB[machine] = float('inf')
        else:
            UCB[machine] = Q[machine] + math.sqrt(
                (2 * math.log(play)) / N[machine]
            )

    # Select machine with highest UCB
    selected_machine = max(machines, key=lambda x: UCB[x])

    print(f"\nPlay {play}")
    print(f"UCB Values: A = {UCB['A']:.4f}, "
          f"B = {UCB['B']:.4f}, "
          f"C = {UCB['C']:.4f}")

    print(f"Selected Machine = {selected_machine}")

    # Part D - Reward Collection
    reward = float(input(f"Enter reward for machine {selected_machine}: "))

    # Part E - Update N, R and Q
    N[selected_machine] += 1
    R[selected_machine] += reward

    # Incremental sample-average formula
    Q[selected_machine] = Q[selected_machine] + (
        (reward - Q[selected_machine]) / N[selected_machine]
    )

    total_reward += reward

    print(f"N({selected_machine}) = {N[selected_machine]}")
    print(f"R({selected_machine}) = {R[selected_machine]:.2f}")
    print(f"Q({selected_machine}) = {Q[selected_machine]:.4f}")


# Part F - Display final results
print("\n\n========== FINAL RESULTS ==========")

print("\nMachine\tN\tR\tUCB\t\tQ")

for machine in machines:
    print(f"{machine}\t{N[machine]}\t{R[machine]:.2f}\t"
          f"{UCB[machine]:.4f}\t\t{Q[machine]:.4f}")

print(f"\nTotal Reward = {total_reward:.2f}")
# Out:
# ----- UCB Multi-Armed Bandit -----
#
# Play 1
# UCB Values: A = inf, B = inf, C = inf
# Selected Machine = A
# Enter reward for machine A: 5
# N(A) = 1
# R(A) = 5.00
# Q(A) = 5.0000
#
# Play 2
# UCB Values: A = 6.1774, B = inf, C = inf
# Selected Machine = B
# Enter reward for machine B: 3
# N(B) = 1
# R(B) = 3.00
# Q(B) = 3.0000
#
# Play 3
# UCB Values: A = 6.4823, B = 4.4823, C = inf
# Selected Machine = C
# Enter reward for machine C: 4
# N(C) = 1
# R(C) = 4.00
# Q(C) = 4.0000
#
# Play 4
# UCB Values: A = 6.6651, B = 4.6651, C = 5.6651
# Selected Machine = A
# Enter reward for machine A: 6
# N(A) = 2
# R(A) = 11.00
# Q(A) = 5.5000
#
# Play 5
# UCB Values: A = 6.7686, B = 4.7941, C = 5.7941
# Selected Machine = A
# Enter reward for machine A: 2
# N(A) = 3
# R(A) = 13.00
# Q(A) = 4.3333
#
# Play 6
# UCB Values: A = 5.4263, B = 4.8930, C = 5.8930
# Selected Machine = C
# Enter reward for machine C: 5
# N(C) = 2
# R(C) = 9.00
# Q(C) = 4.5000
#
# Play 7
# UCB Values: A = 5.4723, B = 4.9728, C = 5.8950
# Selected Machine = C
# Enter reward for machine C: 7
# N(C) = 3
# R(C) = 16.00
# Q(C) = 5.3333
#
# Play 8
# UCB Values: A = 5.5107, B = 5.0393, C = 6.5107
# Selected Machine = C
# Enter reward for machine C: 4
# N(C) = 4
# R(C) = 20.00
# Q(C) = 5.0000
#
# Play 9
# UCB Values: A = 5.5436, B = 5.0963, C = 6.0481
# Selected Machine = C
# Enter reward for machine C: 6
# N(C) = 5
# R(C) = 26.00
# Q(C) = 5.2000
#
# Play 10
# UCB Values: A = 5.5723, B = 5.1460, C = 6.1597
# Selected Machine = C
# Enter reward for machine C: 3
# N(C) = 6
# R(C) = 29.00
# Q(C) = 4.8333
#
#
# ========== FINAL RESULTS ==========
#
# Machine	N	R	UCB		Q
# A	3	13.00	5.5723		4.3333
# B	1	3.00	5.1460		3.0000
# C	6	29.00	6.1597		4.8333
#
# Total Reward = 45.00
