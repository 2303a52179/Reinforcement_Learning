# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52179/Reinforcement_Learning/blob/main/RL_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym
import random


def run_random_agent(env_name):
    print("\n========================================")
    print(f"Environment: {env_name}")
    print("========================================")

    # Step 1: Create environment
    env = gym.make(env_name)

    # Step 2: Reset environment
    state, info = env.reset()

    print("Initial State:", state)
    print("Action Space:", env.action_space)

    total_reward = 0
    step_count = 0

    # Step 3-8: Agent-environment interaction
    while True:

        # Step 5: Select a random action
        action = env.action_space.sample()

        # Step 6: Execute action
        next_state, reward, terminated, truncated, info = env.step(action)

        step_count += 1
        total_reward += reward

        print(
            f"Step {step_count}: "
            f"State = {state}, "
            f"Action = {action}, "
            f"Reward = {reward}, "
            f"Next State = {next_state}"
        )

        # Update state
        state = next_state

        # Step 8: Check whether episode is finished
        if terminated or truncated:
            break

    # Step 9: Calculate average reward
    average_reward = total_reward / step_count

    print("\nEpisode Finished")
    print("Total Reward:", total_reward)
    print("Number of Steps:", step_count)
    print("Average Reward:", round(average_reward, 4))

    env.close()


# Run Random Agent on all three environments
run_random_agent("CartPole-v1")
run_random_agent("MountainCar-v0")
run_random_agent("FrozenLake-v1")
# Out:
# ========================================
# Environment: CartPole-v1
# ========================================
# Initial State: [-0.01111022 -0.03005721  0.04644515 -0.03479882]
# Action Space: Discrete(2)
# Step 1: State = [-0.01111022 -0.03005721  0.04644515 -0.03479882], Action = 0, Reward = 1.0, Next State = [-0.01171136 -0.22581336  0.04574918  0.27216873]
# Step 2: State = [-0.01171136 -0.22581336  0.04574918  0.27216873], Action = 0, Reward = 1.0, Next State = [-0.01622763 -0.42155725  0.05119255  0.5789229 ]
# Step 3: State = [-0.01622763 -0.42155725  0.05119255  0.5789229 ], Action = 1, Reward = 1.0, Next State = [-0.02465877 -0.22718869  0.06277101  0.30279607]
# Step 4: State = [-0.02465877 -0.22718869  0.06277101  0.30279607], Action = 1, Reward = 1.0, Next State = [-0.02920255 -0.03301491  0.06882693  0.03055157]
# Step 5: State = [-0.02920255 -0.03301491  0.06882693  0.03055157], Action = 0, Reward = 1.0, Next State = [-0.02986285 -0.22905292  0.06943797  0.3441315 ]
# Step 6: State = [-0.02986285 -0.22905292  0.06943797  0.3441315 ], Action = 1, Reward = 1.0, Next State = [-0.0344439  -0.03498395  0.0763206   0.07412793]
# Step 7: State = [-0.0344439  -0.03498395  0.0763206   0.07412793], Action = 0, Reward = 1.0, Next State = [-0.03514358 -0.23111238  0.07780315  0.38988066]
# Step 8: State = [-0.03514358 -0.23111238  0.07780315  0.38988066], Action = 0, Reward = 1.0, Next State = [-0.03976583 -0.4272474   0.08560076  0.70604426]
# Step 9: State = [-0.03976583 -0.4272474   0.08560076  0.70604426], Action = 0, Reward = 1.0, Next State = [-0.04831078 -0.6234445   0.09972165  1.0243982 ]
# Step 10: State = [-0.04831078 -0.6234445   0.09972165  1.0243982 ], Action = 0, Reward = 1.0, Next State = [-0.06077967 -0.81974286  0.12020961  1.3466525 ]
# Step 11: State = [-0.06077967 -0.81974286  0.12020961  1.3466525 ], Action = 0, Reward = 1.0, Next State = [-0.07717452 -1.0161533   0.14714266  1.6743988 ]
# Step 12: State = [-0.07717452 -1.0161533   0.14714266  1.6743988 ], Action = 1, Reward = 1.0, Next State = [-0.09749759 -0.8230141   0.18063064  1.4309244 ]
# Step 13: State = [-0.09749759 -0.8230141   0.18063064  1.4309244 ], Action = 0, Reward = 1.0, Next State = [-0.11395787 -1.0198469   0.20924912  1.7741872 ]
# Step 14: State = [-0.11395787 -1.0198469   0.20924912  1.7741872 ], Action = 1, Reward = 1.0, Next State = [-0.13435481 -0.82760805  0.24473287  1.5531902 ]
#
# Episode Finished
# Total Reward: 14.0
# Number of Steps: 14
# Average Reward: 1.0
#
# ========================================
# Environment: MountainCar-v0
# ========================================
# Initial State: [-0.5756886  0.       ]
# Action Space: Discrete(3)
# Step 1: State = [-0.5756886  0.       ], Action = 1, Reward = -1.0, Next State = [-5.7529950e-01  3.8908544e-04]
# Step 2: State = [-5.7529950e-01  3.8908544e-04], Action = 1, Reward = -1.0, Next State = [-0.5745242   0.00077529]
# Step 3: State = [-0.5745242   0.00077529], Action = 1, Reward = -1.0, Next State = [-0.5733685   0.00115574]
# Step 4: State = [-0.5733685   0.00115574], Action = 0, Reward = -1.0, Next State = [-5.728408e-01  5.276321e-04]
# Step 5: State = [-5.728408e-01  5.276321e-04], Action = 0, Reward = -1.0, Next State = [-5.7294524e-01 -1.0439430e-04]
# Step 6: State = [-5.7294524e-01 -1.0439430e-04], Action = 1, Reward = -1.0, Next State = [-5.7268089e-01  2.6435376e-04]
# Step 7: State = [-5.7268089e-01  2.6435376e-04], Action = 2, Reward = -1.0, Next State = [-0.57104975  0.00163114]
# Step 8: State = [-0.57104975  0.00163114], Action = 2, Reward = -1.0, Next State = [-0.5680639   0.00298582]
# Step 9: State = [-0.5680639   0.00298582], Action = 0, Reward = -1.0, Next State = [-0.5657456   0.00231832]
# Step 10: State = [-0.5657456   0.00231832], Action = 2, Reward = -1.0, Next State = [-0.56211203  0.00363358]
# Step 11: State = [-0.56211203  0.00363358], Action = 1, Reward = -1.0, Next State = [-0.5581902   0.00392179]
# Step 12: State = [-0.5581902   0.00392179], Action = 0, Reward = -1.0, Next State = [-0.5550095   0.00318076]
# Step 13: State = [-0.5550095   0.00318076], Action = 1, Reward = -1.0, Next State = [-0.5515935   0.00341599]
# Step 14: State = [-0.5515935   0.00341599], Action = 0, Reward = -1.0, Next State = [-0.5489678  0.0026257]
# Step 15: State = [-0.5489678  0.0026257], Action = 0, Reward = -1.0, Next State = [-0.547152    0.00181579]
# Step 16: State = [-0.547152    0.00181579], Action = 0, Reward = -1.0, Next State = [-0.5461597   0.00099229]
# Step 17: State = [-0.5461597   0.00099229], Action = 1, Reward = -1.0, Next State = [-0.5449983   0.00116137]
# Step 18: State = [-0.5449983   0.00116137], Action = 1, Reward = -1.0, Next State = [-0.54367656  0.00132175]
# Step 19: State = [-0.54367656  0.00132175], Action = 1, Reward = -1.0, Next State = [-0.5422043   0.00147225]
# Step 20: State = [-0.5422043   0.00147225], Action = 1, Reward = -1.0, Next State = [-0.5405926   0.00161172]
# Step 21: State = [-0.5405926   0.00161172], Action = 0, Reward = -1.0, Next State = [-0.5398535   0.00073911]
# Step 22: State = [-0.5398535   0.00073911], Action = 2, Reward = -1.0, Next State = [-0.53799254  0.00186098]
# Step 23: State = [-0.53799254  0.00186098], Action = 0, Reward = -1.0, Next State = [-0.5370236  0.0009689]
# Step 24: State = [-0.5370236  0.0009689], Action = 1, Reward = -1.0, Next State = [-0.53595406  0.00106955]
# Step 25: State = [-0.53595406  0.00106955], Action = 2, Reward = -1.0, Next State = [-0.53379184  0.0021622 ]
# Step 26: State = [-0.53379184  0.0021622 ], Action = 0, Reward = -1.0, Next State = [-0.5325532   0.00123863]
# Step 27: State = [-0.5325532   0.00123863], Action = 1, Reward = -1.0, Next State = [-0.53124744  0.00130578]
# Step 28: State = [-0.53124744  0.00130578], Action = 1, Reward = -1.0, Next State = [-0.5298843   0.00136314]
# Step 29: State = [-0.5298843   0.00136314], Action = 0, Reward = -1.0, Next State = [-5.2947402e-01  4.1028325e-04]
# Step 30: State = [-5.2947402e-01  4.1028325e-04], Action = 0, Reward = -1.0, Next State = [-0.53001964 -0.00054565]
# Step 31: State = [-0.53001964 -0.00054565], Action = 1, Reward = -1.0, Next State = [-5.3051716e-01 -4.9750105e-04]
# Step 32: State = [-5.3051716e-01 -4.9750105e-04], Action = 1, Reward = -1.0, Next State = [-5.3096277e-01 -4.4561681e-04]
# Step 33: State = [-5.3096277e-01 -4.4561681e-04], Action = 2, Reward = -1.0, Next State = [-0.5303532   0.00060961]
# Step 34: State = [-0.5303532   0.00060961], Action = 2, Reward = -1.0, Next State = [-0.5286929   0.00166026]
# Step 35: State = [-0.5286929   0.00166026], Action = 1, Reward = -1.0, Next State = [-0.52699447  0.00169847]
# Step 36: State = [-0.52699447  0.00169847], Action = 0, Reward = -1.0, Next State = [-0.5262705   0.00072393]
# Step 37: State = [-0.5262705   0.00072393], Action = 2, Reward = -1.0, Next State = [-0.52452654  0.00174397]
# Step 38: State = [-0.52452654  0.00174397], Action = 0, Reward = -1.0, Next State = [-0.5237756   0.00075093]
# Step 39: State = [-0.5237756   0.00075093], Action = 2, Reward = -1.0, Next State = [-0.5220233   0.00175226]
# Step 40: State = [-0.5220233   0.00175226], Action = 0, Reward = -1.0, Next State = [-0.5212829   0.00074044]
# Step 41: State = [-0.5212829   0.00074044], Action = 2, Reward = -1.0, Next State = [-0.51955986  0.00172307]
# Step 42: State = [-0.51955986  0.00172307], Action = 1, Reward = -1.0, Next State = [-0.517867    0.00169278]
# Step 43: State = [-0.517867    0.00169278], Action = 2, Reward = -1.0, Next State = [-0.51521724  0.0026498 ]
# Step 44: State = [-0.51521724  0.0026498 ], Action = 1, Reward = -1.0, Next State = [-0.51263034  0.00258694]
# Step 45: State = [-0.51263034  0.00258694], Action = 2, Reward = -1.0, Next State = [-0.50912565  0.00350469]
# Step 46: State = [-0.50912565  0.00350469], Action = 1, Reward = -1.0, Next State = [-0.50572944  0.00339618]
# Step 47: State = [-0.50572944  0.00339618], Action = 1, Reward = -1.0, Next State = [-0.5024672   0.00326222]
# Step 48: State = [-0.5024672   0.00326222], Action = 1, Reward = -1.0, Next State = [-0.4993634   0.00310384]
# Step 49: State = [-0.4993634   0.00310384], Action = 1, Reward = -1.0, Next State = [-0.49644116  0.00292224]
# Step 50: State = [-0.49644116  0.00292224], Action = 1, Reward = -1.0, Next State = [-0.49372238  0.00271878]
# Step 51: State = [-0.49372238  0.00271878], Action = 1, Reward = -1.0, Next State = [-0.49122736  0.00249501]
# Step 52: State = [-0.49122736  0.00249501], Action = 2, Reward = -1.0, Next State = [-0.48797476  0.0032526 ]
# Step 53: State = [-0.48797476  0.0032526 ], Action = 1, Reward = -1.0, Next State = [-0.48498884  0.00298593]
# Step 54: State = [-0.48498884  0.00298593], Action = 2, Reward = -1.0, Next State = [-0.48129183  0.003697  ]
# Step 55: State = [-0.48129183  0.003697  ], Action = 2, Reward = -1.0, Next State = [-0.47691128  0.00438055]
# Step 56: State = [-0.47691128  0.00438055], Action = 2, Reward = -1.0, Next State = [-0.47187975  0.00503154]
# Step 57: State = [-0.47187975  0.00503154], Action = 1, Reward = -1.0, Next State = [-0.46723455  0.0046452 ]
# Step 58: State = [-0.46723455  0.0046452 ], Action = 0, Reward = -1.0, Next State = [-0.46401006  0.00322448]
# Step 59: State = [-0.46401006  0.00322448], Action = 1, Reward = -1.0, Next State = [-0.46123013  0.00277994]
# Step 60: State = [-0.46123013  0.00277994], Action = 0, Reward = -1.0, Next State = [-0.45991522  0.0013149 ]
# Step 61: State = [-0.45991522  0.0013149 ], Action = 0, Reward = -1.0, Next State = [-4.6007505e-01 -1.5982498e-04]
# Step 62: State = [-4.6007505e-01 -1.5982498e-04], Action = 2, Reward = -1.0, Next State = [-4.5970842e-01  3.6662552e-04]
# Step 63: State = [-4.5970842e-01  3.6662552e-04], Action = 1, Reward = -1.0, Next State = [-4.59818035e-01 -1.09623594e-04]
# Step 64: State = [-4.59818035e-01 -1.09623594e-04], Action = 1, Reward = -1.0, Next State = [-0.4604031  -0.00058507]
# Step 65: State = [-0.4604031  -0.00058507], Action = 0, Reward = -1.0, Next State = [-0.4624593 -0.0020562]
# Step 66: State = [-0.4624593 -0.0020562], Action = 2, Reward = -1.0, Next State = [-0.46397147 -0.00151218]
# Step 67: State = [-0.46397147 -0.00151218], Action = 1, Reward = -1.0, Next State = [-0.4659285 -0.001957 ]
# Step 68: State = [-0.4659285 -0.001957 ], Action = 2, Reward = -1.0, Next State = [-0.46731585 -0.00138737]
# Step 69: State = [-0.46731585 -0.00138737], Action = 0, Reward = -1.0, Next State = [-0.47012335 -0.00280749]
# Step 70: State = [-0.47012335 -0.00280749], Action = 1, Reward = -1.0, Next State = [-0.4733302  -0.00320684]
# Step 71: State = [-0.4733302  -0.00320684], Action = 0, Reward = -1.0, Next State = [-0.4779126  -0.00458243]
# Step 72: State = [-0.4779126  -0.00458243], Action = 0, Reward = -1.0, Next State = [-0.48383662 -0.005924  ]
# Step 73: State = [-0.48383662 -0.005924  ], Action = 2, Reward = -1.0, Next State = [-0.48905814 -0.00522151]
# Step 74: State = [-0.48905814 -0.00522151], Action = 1, Reward = -1.0, Next State = [-0.49453825 -0.0054801 ]
# Step 75: State = [-0.49453825 -0.0054801 ], Action = 1, Reward = -1.0, Next State = [-0.50023603 -0.00569778]
# Step 76: State = [-0.50023603 -0.00569778], Action = 2, Reward = -1.0, Next State = [-0.5051089  -0.00487286]
# Step 77: State = [-0.5051089  -0.00487286], Action = 2, Reward = -1.0, Next State = [-0.50912035 -0.00401146]
# Step 78: State = [-0.50912035 -0.00401146], Action = 0, Reward = -1.0, Next State = [-0.5142403  -0.00512002]
# Step 79: State = [-0.5142403  -0.00512002], Action = 0, Reward = -1.0, Next State = [-0.52043056 -0.00619019]
# Step 80: State = [-0.52043056 -0.00619019], Action = 1, Reward = -1.0, Next State = [-0.5266445  -0.00621396]
# Step 81: State = [-0.5266445  -0.00621396], Action = 2, Reward = -1.0, Next State = [-0.5318356  -0.00519111]
# Step 82: State = [-0.5318356  -0.00519111], Action = 0, Reward = -1.0, Next State = [-0.53796494 -0.00612934]
# Step 83: State = [-0.53796494 -0.00612934], Action = 0, Reward = -1.0, Next State = [-0.5449866  -0.00702163]
# Step 84: State = [-0.5449866  -0.00702163], Action = 0, Reward = -1.0, Next State = [-0.5528479  -0.00786133]
# Step 85: State = [-0.5528479  -0.00786133], Action = 1, Reward = -1.0, Next State = [-0.5604902  -0.00764224]
# Step 86: State = [-0.5604902  -0.00764224], Action = 0, Reward = -1.0, Next State = [-0.5688563  -0.00836612]
# Step 87: State = [-0.5688563  -0.00836612], Action = 1, Reward = -1.0, Next State = [-0.57688403 -0.00802773]
# Step 88: State = [-0.57688403 -0.00802773], Action = 2, Reward = -1.0, Next State = [-0.5835138  -0.00662979]
# Step 89: State = [-0.5835138  -0.00662979], Action = 2, Reward = -1.0, Next State = [-0.58869666 -0.00518285]
# Step 90: State = [-0.58869666 -0.00518285], Action = 1, Reward = -1.0, Next State = [-0.5933944  -0.00469771]
# Step 91: State = [-0.5933944  -0.00469771], Action = 2, Reward = -1.0, Next State = [-0.59657246 -0.00317806]
# Step 92: State = [-0.59657246 -0.00317806], Action = 2, Reward = -1.0, Next State = [-0.59820753 -0.00163512]
# Step 93: State = [-0.59820753 -0.00163512], Action = 1, Reward = -1.0, Next State = [-0.59928775 -0.00108021]
# Step 94: State = [-0.59928775 -0.00108021], Action = 2, Reward = -1.0, Next State = [-5.9880519e-01  4.8258773e-04]
# Step 95: State = [-5.9880519e-01  4.8258773e-04], Action = 0, Reward = -1.0, Next State = [-5.9876335e-01  4.1862582e-05]
# Step 96: State = [-5.9876335e-01  4.1862582e-05], Action = 1, Reward = -1.0, Next State = [-0.5981625   0.00060083]
# Step 97: State = [-0.5981625   0.00060083], Action = 0, Reward = -1.0, Next State = [-5.9800708e-01  1.5540721e-04]
# Step 98: State = [-5.9800708e-01  1.5540721e-04], Action = 2, Reward = -1.0, Next State = [-0.5962982   0.00170885]
# Step 99: State = [-0.5962982   0.00170885], Action = 0, Reward = -1.0, Next State = [-0.5950485   0.00124978]
# Step 100: State = [-0.5950485   0.00124978], Action = 2, Reward = -1.0, Next State = [-0.5922669   0.00278156]
# Step 101: State = [-0.5922669   0.00278156], Action = 1, Reward = -1.0, Next State = [-0.58897394  0.00329293]
# Step 102: State = [-0.58897394  0.00329293], Action = 1, Reward = -1.0, Next State = [-0.5851939   0.00378011]
# Step 103: State = [-0.5851939   0.00378011], Action = 0, Reward = -1.0, Next State = [-0.5819544   0.00323945]
# Step 104: State = [-0.5819544   0.00323945], Action = 2, Reward = -1.0, Next State = [-0.5772795   0.00467488]
# Step 105: State = [-0.5772795   0.00467488], Action = 1, Reward = -1.0, Next State = [-0.57220376  0.00507575]
# Step 106: State = [-0.57220376  0.00507575], Action = 2, Reward = -1.0, Next State = [-0.5657648  0.006439 ]
# Step 107: State = [-0.5657648  0.006439 ], Action = 2, Reward = -1.0, Next State = [-0.55801034  0.0077544 ]
# Step 108: State = [-0.55801034  0.0077544 ], Action = 0, Reward = -1.0, Next State = [-0.55099833  0.00701203]
# Step 109: State = [-0.55099833  0.00701203], Action = 2, Reward = -1.0, Next State = [-0.54278105  0.0082173 ]
# Step 110: State = [-0.54278105  0.0082173 ], Action = 2, Reward = -1.0, Next State = [-0.53341997  0.00936108]
# Step 111: State = [-0.53341997  0.00936108], Action = 1, Reward = -1.0, Next State = [-0.5239852   0.00943473]
# Step 112: State = [-0.5239852   0.00943473], Action = 0, Reward = -1.0, Next State = [-0.5155476   0.00843763]
# Step 113: State = [-0.5155476   0.00843763], Action = 2, Reward = -1.0, Next State = [-0.50617033  0.00937725]
# Step 114: State = [-0.50617033  0.00937725], Action = 2, Reward = -1.0, Next State = [-0.49592376  0.0102466 ]
# Step 115: State = [-0.49592376  0.0102466 ], Action = 2, Reward = -1.0, Next State = [-0.48488447  0.01103927]
# Step 116: State = [-0.48488447  0.01103927], Action = 1, Reward = -1.0, Next State = [-0.4741349   0.01074957]
# Step 117: State = [-0.4741349   0.01074957], Action = 0, Reward = -1.0, Next State = [-0.46475494  0.00937995]
# Step 118: State = [-0.46475494  0.00937995], Action = 1, Reward = -1.0, Next State = [-0.45581403  0.00894091]
# Step 119: State = [-0.45581403  0.00894091], Action = 2, Reward = -1.0, Next State = [-0.44637802  0.00943602]
# Step 120: State = [-0.44637802  0.00943602], Action = 2, Reward = -1.0, Next State = [-0.436516    0.00986203]
# Step 121: State = [-0.436516    0.00986203], Action = 2, Reward = -1.0, Next State = [-0.42629966  0.01021632]
# Step 122: State = [-0.42629966  0.01021632], Action = 1, Reward = -1.0, Next State = [-0.4168028   0.00949689]
# Step 123: State = [-0.4168028   0.00949689], Action = 2, Reward = -1.0, Next State = [-0.40709323  0.00970955]
# Step 124: State = [-0.40709323  0.00970955], Action = 2, Reward = -1.0, Next State = [-0.39723977  0.00985344]
# Step 125: State = [-0.39723977  0.00985344], Action = 0, Reward = -1.0, Next State = [-0.3893115   0.00792829]
# Step 126: State = [-0.3893115   0.00792829], Action = 0, Reward = -1.0, Next State = [-0.38336334  0.00594815]
# Step 127: State = [-0.38336334  0.00594815], Action = 1, Reward = -1.0, Next State = [-0.3784362   0.00492714]
# Step 128: State = [-0.3784362   0.00492714], Action = 1, Reward = -1.0, Next State = [-0.3745637   0.00387251]
# Step 129: State = [-0.3745637   0.00387251], Action = 1, Reward = -1.0, Next State = [-0.37177208  0.00279162]
# Step 130: State = [-0.37177208  0.00279162], Action = 0, Reward = -1.0, Next State = [-0.3710802   0.00069188]
# Step 131: State = [-0.3710802   0.00069188], Action = 1, Reward = -1.0, Next State = [-0.3714927  -0.00041251]
# Step 132: State = [-0.3714927  -0.00041251], Action = 0, Reward = -1.0, Next State = [-0.37400684 -0.00251412]
# Step 133: State = [-0.37400684 -0.00251412], Action = 0, Reward = -1.0, Next State = [-0.3786056  -0.00459878]
# Step 134: State = [-0.3786056  -0.00459878], Action = 1, Reward = -1.0, Next State = [-0.38425785 -0.00565226]
# Step 135: State = [-0.38425785 -0.00565226], Action = 2, Reward = -1.0, Next State = [-0.389925   -0.00566715]
# Step 136: State = [-0.389925   -0.00566715], Action = 1, Reward = -1.0, Next State = [-0.39656806 -0.00664304]
# Step 137: State = [-0.39656806 -0.00664304], Action = 1, Reward = -1.0, Next State = [-0.40414092 -0.00757288]
# Step 138: State = [-0.40414092 -0.00757288], Action = 0, Reward = -1.0, Next State = [-0.4135907  -0.00944976]
# Step 139: State = [-0.4135907  -0.00944976], Action = 0, Reward = -1.0, Next State = [-0.4248506  -0.01125992]
# Step 140: State = [-0.4248506  -0.01125992], Action = 1, Reward = -1.0, Next State = [-0.43684036 -0.01198975]
# Step 141: State = [-0.43684036 -0.01198975], Action = 1, Reward = -1.0, Next State = [-0.44947347 -0.01263312]
# Step 142: State = [-0.44947347 -0.01263312], Action = 2, Reward = -1.0, Next State = [-0.46165797 -0.01218448]
# Step 143: State = [-0.46165797 -0.01218448], Action = 0, Reward = -1.0, Next State = [-0.47530434 -0.01364637]
# Step 144: State = [-0.47530434 -0.01364637], Action = 0, Reward = -1.0, Next State = [-0.49031165 -0.01500731]
# Step 145: State = [-0.49031165 -0.01500731], Action = 2, Reward = -1.0, Next State = [-0.5045682  -0.01425655]
# Step 146: State = [-0.5045682  -0.01425655], Action = 0, Reward = -1.0, Next State = [-0.5199674 -0.0153992]
# Step 147: State = [-0.5199674 -0.0153992], Action = 2, Reward = -1.0, Next State = [-0.53439385 -0.01442644]
# Step 148: State = [-0.53439385 -0.01442644], Action = 0, Reward = -1.0, Next State = [-0.54973936 -0.01534549]
# Step 149: State = [-0.54973936 -0.01534549], Action = 2, Reward = -1.0, Next State = [-0.56388897 -0.01414964]
# Step 150: State = [-0.56388897 -0.01414964], Action = 1, Reward = -1.0, Next State = [-0.57773715 -0.0138482 ]
# Step 151: State = [-0.57773715 -0.0138482 ], Action = 1, Reward = -1.0, Next State = [-0.5911811  -0.01344394]
# Step 152: State = [-0.5911811  -0.01344394], Action = 1, Reward = -1.0, Next State = [-0.6041216  -0.01294054]
# Step 153: State = [-0.6041216  -0.01294054], Action = 0, Reward = -1.0, Next State = [-0.6174641  -0.01334247]
# Step 154: State = [-0.6174641  -0.01334247], Action = 2, Reward = -1.0, Next State = [-0.6291119  -0.01164775]
# Step 155: State = [-0.6291119  -0.01164775], Action = 0, Reward = -1.0, Next State = [-0.64098144 -0.01186955]
# Step 156: State = [-0.64098144 -0.01186955], Action = 0, Reward = -1.0, Next State = [-0.6529887  -0.01200726]
# Step 157: State = [-0.6529887  -0.01200726], Action = 2, Reward = -1.0, Next State = [-0.6630497  -0.01006103]
# Step 158: State = [-0.6630497  -0.01006103], Action = 0, Reward = -1.0, Next State = [-0.6730951  -0.01004539]
# Step 159: State = [-0.6730951  -0.01004539], Action = 0, Reward = -1.0, Next State = [-0.6830565  -0.00996138]
# Step 160: State = [-0.6830565  -0.00996138], Action = 1, Reward = -1.0, Next State = [-0.691867   -0.00881054]
# Step 161: State = [-0.691867   -0.00881054], Action = 2, Reward = -1.0, Next State = [-0.69846845 -0.00660145]
# Step 162: State = [-0.69846845 -0.00660145], Action = 1, Reward = -1.0, Next State = [-0.7038177  -0.00534926]
# Step 163: State = [-0.7038177  -0.00534926], Action = 1, Reward = -1.0, Next State = [-0.70788026 -0.00406251]
# Step 164: State = [-0.70788026 -0.00406251], Action = 1, Reward = -1.0, Next State = [-0.71062994 -0.00274974]
# Step 165: State = [-0.71062994 -0.00274974], Action = 0, Reward = -1.0, Next State = [-0.7130494  -0.00241946]
# Step 166: State = [-0.7130494  -0.00241946], Action = 1, Reward = -1.0, Next State = [-0.71412325 -0.00107385]
# Step 167: State = [-0.71412325 -0.00107385], Action = 1, Reward = -1.0, Next State = [-7.1384472e-01  2.7854423e-04]
# Step 168: State = [-7.1384472e-01  2.7854423e-04], Action = 1, Reward = -1.0, Next State = [-0.71221554  0.00162918]
# Step 169: State = [-0.71221554  0.00162918], Action = 1, Reward = -1.0, Next State = [-0.70924604  0.00296951]
# Step 170: State = [-0.70924604  0.00296951], Action = 1, Reward = -1.0, Next State = [-0.70495504  0.00429099]
# Step 171: State = [-0.70495504  0.00429099], Action = 0, Reward = -1.0, Next State = [-0.70037     0.00458505]
# Step 172: State = [-0.70037     0.00458505], Action = 1, Reward = -1.0, Next State = [-0.6945204   0.00584956]
# Step 173: State = [-0.6945204   0.00584956], Action = 2, Reward = -1.0, Next State = [-0.6864444   0.00807603]
# Step 174: State = [-0.6864444   0.00807603], Action = 2, Reward = -1.0, Next State = [-0.676195    0.01024936]
# Step 175: State = [-0.676195    0.01024936], Action = 2, Reward = -1.0, Next State = [-0.6638408   0.01235428]
# Step 176: State = [-0.6638408   0.01235428], Action = 0, Reward = -1.0, Next State = [-0.6514654   0.01237534]
# Step 177: State = [-0.6514654   0.01237534], Action = 2, Reward = -1.0, Next State = [-0.63715446  0.01431099]
# Step 178: State = [-0.63715446  0.01431099], Action = 1, Reward = -1.0, Next State = [-0.62200814  0.01514628]
# Step 179: State = [-0.62200814  0.01514628], Action = 0, Reward = -1.0, Next State = [-0.60713446  0.01487368]
# Step 180: State = [-0.60713446  0.01487368], Action = 2, Reward = -1.0, Next State = [-0.59064084  0.01649366]
# Step 181: State = [-0.59064084  0.01649366], Action = 2, Reward = -1.0, Next State = [-0.57264775  0.01799309]
# Step 182: State = [-0.57264775  0.01799309], Action = 2, Reward = -1.0, Next State = [-0.5532881   0.01935963]
# Step 183: State = [-0.5532881   0.01935963], Action = 2, Reward = -1.0, Next State = [-0.53270614  0.020582  ]
# Step 184: State = [-0.53270614  0.020582  ], Action = 1, Reward = -1.0, Next State = [-0.5120558  0.0206503]
# Step 185: State = [-0.5120558  0.0206503], Action = 0, Reward = -1.0, Next State = [-0.49249208  0.01956375]
# Step 186: State = [-0.49249208  0.01956375], Action = 1, Reward = -1.0, Next State = [-0.47316128  0.01933078]
# Step 187: State = [-0.47316128  0.01933078], Action = 2, Reward = -1.0, Next State = [-0.45320734  0.01995395]
# Step 188: State = [-0.45320734  0.01995395], Action = 1, Reward = -1.0, Next State = [-0.43377742  0.01942992]
# Step 189: State = [-0.43377742  0.01942992], Action = 1, Reward = -1.0, Next State = [-0.41501302  0.01876439]
# Step 190: State = [-0.41501302  0.01876439], Action = 0, Reward = -1.0, Next State = [-0.3980487   0.01696432]
# Step 191: State = [-0.3980487   0.01696432], Action = 0, Reward = -1.0, Next State = [-0.3830039  0.0150448]
# Step 192: State = [-0.3830039  0.0150448], Action = 2, Reward = -1.0, Next State = [-0.36798257  0.01502133]
# Step 193: State = [-0.36798257  0.01502133], Action = 2, Reward = -1.0, Next State = [-0.35308644  0.01489614]
# Step 194: State = [-0.35308644  0.01489614], Action = 0, Reward = -1.0, Next State = [-0.34041408  0.01267235]
# Step 195: State = [-0.34041408  0.01267235], Action = 1, Reward = -1.0, Next State = [-0.3290475   0.01136658]
# Step 196: State = [-0.3290475   0.01136658], Action = 0, Reward = -1.0, Next State = [-0.3200586   0.00898889]
# Step 197: State = [-0.3200586   0.00898889], Action = 2, Reward = -1.0, Next State = [-0.31150317  0.00855545]
# Step 198: State = [-0.31150317  0.00855545], Action = 0, Reward = -1.0, Next State = [-0.30543324  0.00606992]
# Step 199: State = [-0.30543324  0.00606992], Action = 1, Reward = -1.0, Next State = [-0.30088523  0.00454802]
# Step 200: State = [-0.30088523  0.00454802], Action = 1, Reward = -1.0, Next State = [-0.29788604  0.0029992 ]
#
# Episode Finished
# Total Reward: -200.0
# Number of Steps: 200
# Average Reward: -1.0
#
# ========================================
# Environment: FrozenLake-v1
# ========================================
# Initial State: 0
# Action Space: Discrete(4)
# Step 1: State = 0, Action = 3, Reward = 0, Next State = 1
# Step 2: State = 1, Action = 3, Reward = 0, Next State = 1
# Step 3: State = 1, Action = 1, Reward = 0, Next State = 5
#
# Episode Finished
# Total Reward: 0
# Number of Steps: 3
# Average Reward: 0.0
